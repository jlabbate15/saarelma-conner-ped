# %% [markdown]
# setup this test with profiles_loop_solve.py

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(ROOT))
from src.profiles_loop_solve import profiles_loop_solve
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified

# %%
verbose = False

MHD_FP = Path('/mnt/homes_global/jal2351/software/sc_inputs/CAKEgeqdsks/g158091.01935') # filepath to MHD paramter file
KPROF_FP = Path('/mnt/homes_global/jal2351/software/sc_inputs/CAKEpfiles/p158091.01935')

# Output data and files
ne_success_fp = 'success_profloop'

# Scan parameters
x_res = 40
eped_tol_max = 1e-2
free_params = {
    'alpha_crit': 3.16,
    'C_KBM': 0.1,
    'De_chie_etg': 3.16,
    'nFC_x0': 1e16,
    'ncx_x0_ratio': 2.44
}

# %%
profiles_loop_solve(
    MHD_FP = MHD_FP,
    KPROF_FP = KPROF_FP,
    ne_success_fp = ne_success_fp,
    x_res = x_res,
    eped_tol_max = eped_tol_max,
    free_params = free_params,
    verbose = verbose,
)
# Out:
# Setting up EPEDNN...
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Base model built.
# Pedestal height: 0.008535702801349498 MPa, Pedestal width: 0.035398762940260516 (psi_N)
#   Te_ped = 1292.3 eV, T_sep = 155.1 eV (ne_ped = 2.061e+19 m^-3, psi_ped = 0.9646, Delta = 0.0354)
#   psi_N_inner_boundary_new = 0.9646
# Percent change from previous T_e at psi_ped = 35.1014
# Setting up EPEDNN...
# Pedestal height: 0.009544760904643679 MPa, Pedestal width: 0.03749909154938921 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.17754956121385673
#   Te_ped = 1397.3 eV, T_sep = 155.1 eV (ne_ped = 2.132e+19 m^-3, psi_ped = 0.9625, Delta = 0.0375)
#   psi_N_inner_boundary_new = 0.9625
# Percent change from previous T_e at psi_ped = 6.3180
# Setting up EPEDNN...
# Pedestal height: 0.009812703933696008 MPa, Pedestal width: 0.03804979393015234 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.04275801460982326
#   Te_ped = 1440.9 eV, T_sep = 155.1 eV (ne_ped = 2.125e+19 m^-3, psi_ped = 0.9620, Delta = 0.0380)
#   psi_N_inner_boundary_new = 0.9620
# Percent change from previous T_e at psi_ped = 2.7003
# Setting up EPEDNN...
# Pedestal height: 0.009937273819386023 MPa, Pedestal width: 0.038301352675291306 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.019306060107771913
#   Te_ped = 1462.3 eV, T_sep = 155.1 eV (ne_ped = 2.121e+19 m^-3, psi_ped = 0.9617, Delta = 0.0383)
#   psi_N_inner_boundary_new = 0.9617
# Percent change from previous T_e at psi_ped = 1.2958
# Setting up EPEDNN...
# Pedestal height: 0.00999934873924057 MPa, Pedestal width: 0.03842492175257178 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.00947290771337763
