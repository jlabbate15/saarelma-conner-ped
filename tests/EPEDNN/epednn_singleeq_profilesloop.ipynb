# %% [markdown]
# setup this test with profiles_loop_solve.py

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(ROOT))
from src.profiles_loop_solve import profiles_loop_solve
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified

# %%
verbose = False

MHD_FP = Path('/mnt/homes_global/jal2351/software/sc_inputs/CAKEgeqdsks/g158091.01935') # filepath to MHD paramter file
KPROF_FP = Path('/mnt/homes_global/jal2351/software/sc_inputs/CAKEpfiles/p158091.01935')

# Output data and files
ne_success_fp = 'success_profloop_1'

# Scan parameters
x_res = 20
eped_tol_max = 1e-5
EPEDNN_core = 'previous T, stiched ne'
free_params = {
    'alpha_crit': 3.16,
    'C_KBM': 0.1,
    'De_chie_etg': 3.16,
    'nFC_x0': 1e16,
    'ncx_x0_ratio': 2.44
}

# %%
pedestal_width, pedestal_height, gfile_pres, gfile_pres_grid =  profiles_loop_solve(
                                                                                    MHD_FP = MHD_FP,
                                                                                    KPROF_FP = KPROF_FP,
                                                                                    ne_success_fp = ne_success_fp,
                                                                                    x_res = x_res,
                                                                                    eped_tol_max = eped_tol_max,
                                                                                    free_params = free_params,
                                                                                    EPEDNN_core = EPEDNN_core,
                                                                                    verbose = verbose,
                                                                                )
# Out:
# Setting up EPEDNN...
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Base model built.
# betan: [1.20080331]
# Pedestal height: 0.008486393228264288 MPa, Pedestal width: 0.03507496659282044 (psi_N)
# Setting up EPEDNN...
# betan: [1.39175622]
# Pedestal height: 0.008172713141255068 MPa, Pedestal width: 0.03469740868289167 (psi_N)
# Normalized pedestal pressure height and width tolerance: -0.04772702217558278
# Setting up EPEDNN...
# betan: [1.35917668]
# Pedestal height: 0.008241579811804527 MPa, Pedestal width: 0.03481558749654749 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.011832398599887096
# Setting up EPEDNN...
# betan: [1.36061943]
# Pedestal height: 0.00823757997282516 MPa, Pedestal width: 0.03480832189426509 (psi_N)
# Normalized pedestal pressure height and width tolerance: -0.0006940125030716728
# Setting up EPEDNN...
# betan: [1.36063929]
# Pedestal height: 0.008237627443404208 MPa, Pedestal width: 0.034808455956417454 (psi_N)
# Normalized pedestal pressure height and width tolerance: 9.614124747456097e-06
