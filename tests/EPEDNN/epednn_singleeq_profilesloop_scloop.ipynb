# %% [markdown]
# setup this test with profiles_loop_solve.py

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(ROOT))
from src.profiles_loop_solve import profiles_loop_solve
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified

# %%
verbose = False

MHD_FP = Path('/mnt/homes_global/jal2351/software/sc_inputs/CAKEgeqdsks/g158091.01935') # filepath to MHD paramter file
KPROF_FP = Path('/mnt/homes_global/jal2351/software/sc_inputs/CAKEpfiles/p158091.01935')

# Output data and files
success_fp = 'success_PTHmode.txt'
failure_fp = 'failure_PTHmode.txt'
error_messages_fp = 'error_messages_PTHmode.txt'
with open(success_fp, 'w') as f:
        f.write(f"alpha_crit, C_KBM, De_chie_etg, nFC_x0, ncx_x0_ratio, psi_N_inner\n")
with open(failure_fp, 'w') as f:
        f.write(f"alpha_crit, C_KBM, De_chie_etg, nFC_x0, ncx_x0_ratio, psi_N_inner\n")
with open(error_messages_fp, 'w') as f:
        f.write(f"alpha_crit, C_KBM, De_chie_etg, nFC_x0, ncx_x0_ratio, psi_N_inner, message\n")
ne_success_fp = 'success_profloop'

# Scan parameters
N = 3
x_res = 40
eped_tol_max = 1e-5

# %%
profiles_loop_solve(
    MHD_FP = MHD_FP,
    KPROF_FP = KPROF_FP,
    ne_success_fp = ne_success_fp,
    success_fp = success_fp,
    failure_fp = failure_fp,
    error_messages_fp = error_messages_fp,
    N = N,
    x_res = x_res,
    eped_tol_max = eped_tol_max,
    verbose = verbose,
)
# Out:
# Setting up EPEDNN...
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Base model built.
# EPED iter 0: 106 successful runs (best -> worst L2)
#   #  1  L2=0.0269  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   #  2  L2=0.0591  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #  3  L2=0.0628  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   #  4  L2=0.0652  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   #  5  L2=0.0821  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #  6  L2=0.1048  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   #  7  L2=0.1200  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #  8  L2=0.1292  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #  9  L2=0.1354  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 10  L2=0.1363  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 11  L2=0.1534  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 12  L2=0.1672  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 13  L2=0.1731  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 14  L2=0.2087  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 15  L2=0.2122  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 16  L2=0.2231  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+18, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 17  L2=0.2231  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 18  L2=0.2234  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 19  L2=0.2274  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 20  L2=0.2331  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 21  L2=0.2429  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 22  L2=0.2525  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 23  L2=0.2587  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 24  L2=0.2596  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 25  L2=0.2622  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 26  L2=0.2631  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 27  L2=0.2635  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 28  L2=0.2661  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 29  L2=0.2667  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 30  L2=0.2669  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 31  L2=0.2678  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 32  L2=0.2741  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 33  L2=0.2782  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 34  L2=0.2810  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 35  L2=0.2943  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 36  L2=0.2993  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 37  L2=0.2996  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 38  L2=0.3018  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 39  L2=0.3026  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 40  L2=0.3037  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 41  L2=0.3050  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 42  L2=0.3051  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 43  L2=0.3055  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+18, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 44  L2=0.3057  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 45  L2=0.3079  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 46  L2=0.3108  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 47  L2=0.3203  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 48  L2=0.3228  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 49  L2=0.3249  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 50  L2=0.3255  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 51  L2=0.3258  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 52  L2=0.3291  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 53  L2=0.3382  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 54  L2=0.3421  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 55  L2=0.3521  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 56  L2=0.3662  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 57  L2=0.3668  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 58  L2=0.3678  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 59  L2=0.3706  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 60  L2=0.3749  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 61  L2=0.3781  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 62  L2=0.3784  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 63  L2=0.3813  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 64  L2=0.3813  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 65  L2=0.3825  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 66  L2=0.3828  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 67  L2=0.3828  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 68  L2=0.3851  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 69  L2=0.3938  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 70  L2=0.3959  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 71  L2=0.3997  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 72  L2=0.4005  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+18, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 73  L2=0.4005  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 74  L2=0.4013  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 75  L2=0.4055  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 76  L2=0.4097  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 77  L2=0.4119  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 78  L2=0.4130  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 79  L2=0.4138  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 80  L2=0.4140  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 81  L2=0.4180  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 82  L2=0.4290  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 83  L2=0.4291  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 84  L2=0.4304  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 85  L2=0.4344  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 86  L2=0.4347  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 87  L2=0.4358  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 88  L2=0.4443  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 89  L2=0.4485  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 90  L2=0.4514  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 91  L2=0.4514  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 92  L2=0.4516  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 93  L2=0.4542  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 94  L2=0.4562  alpha_crit=0.1, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 95  L2=0.4602  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 96  L2=0.4620  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   # 97  L2=0.4625  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   # 98  L2=0.4706  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   # 99  L2=0.4729  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #100  L2=0.4735  alpha_crit=0.1, C_KBM=10.0, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   #101  L2=0.5277  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   #102  L2=0.5309  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #103  L2=0.5490  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=1.0, nFC_x0=1e+18, ncx_x0_ratio=1.259, psi_N_inner=0.85
#   #104  L2=0.6538  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.85
#   #105  L2=0.8434  alpha_crit=0.1, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
#   #106  L2=0.9764  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.85
# Best normalized L2 = 0.0269
# Pedestal height: 0.00859185807992445 MPa, Pedestal width: 0.03549679460578433 (psi_N)
#   Te_ped = 1316.4 eV, T_sep = 155.1 eV (ne_ped = 2.037e+19 m^-3, psi_ped = 0.9645, Delta = 0.0355)
#   psi_N_inner_boundary_new = 0.9645
# Percent change from previous T_e at psi_ped = 37.4768
# Setting up EPEDNN...
# EPED iter 1: 25 successful runs (best -> worst L2)
#   #  1  L2=0.2872  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   #  2  L2=0.2874  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   #  3  L2=0.2882  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   #  4  L2=0.2958  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   #  5  L2=0.3105  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   #  6  L2=0.3107  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   #  7  L2=0.3114  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   #  8  L2=0.3175  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   #  9  L2=0.3217  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   # 10  L2=0.3358  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   # 11  L2=0.3367  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   # 12  L2=0.3376  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   # 13  L2=0.3448  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   # 14  L2=0.4146  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   # 15  L2=0.4200  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   # 16  L2=0.4619  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   # 17  L2=0.5727  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   # 18  L2=0.5727  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   # 19  L2=0.5730  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   # 20  L2=0.5750  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   # 21  L2=0.5780  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   # 22  L2=0.5786  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
#   # 23  L2=0.5809  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9645032053942156
#   # 24  L2=0.6257  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9645032053942156
#   # 25  L2=0.6312  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9645032053942156
# Best normalized L2 = 0.2872
# Pedestal height: 0.00905539055102489 MPa, Pedestal width: 0.03675935827662011 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.08951858647967123
#   Te_ped = 1442.0 eV, T_sep = 155.1 eV (ne_ped = 1.960e+19 m^-3, psi_ped = 0.9632, Delta = 0.0368)
#   psi_N_inner_boundary_new = 0.9632
# Percent change from previous T_e at psi_ped = 8.4498
# Setting up EPEDNN...
# EPED iter 2: 29 successful runs (best -> worst L2)
#   #  1  L2=0.2077  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   #  2  L2=0.2079  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   #  3  L2=0.2086  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   #  4  L2=0.2149  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   #  5  L2=0.2173  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   #  6  L2=0.2175  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   #  7  L2=0.2180  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   #  8  L2=0.2233  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   #  9  L2=0.2380  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 10  L2=0.2398  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 11  L2=0.2402  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 12  L2=0.2415  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 13  L2=0.2479  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   # 14  L2=0.3135  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 15  L2=0.3184  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   # 16  L2=0.3769  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   # 17  L2=0.4388  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 18  L2=0.4388  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 19  L2=0.4391  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   # 20  L2=0.4411  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 21  L2=0.4441  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 22  L2=0.4447  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 23  L2=0.4469  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   # 24  L2=0.4470  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 25  L2=0.4665  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 26  L2=0.4692  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
#   # 27  L2=0.4916  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9632406417233799
#   # 28  L2=0.4969  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9632406417233799
#   # 29  L2=0.5167  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9632406417233799
# Best normalized L2 = 0.2077
# Pedestal height: 0.009390785676015567 MPa, Pedestal width: 0.03742382904664127 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.05511440757207098
#   Te_ped = 1542.2 eV, T_sep = 155.1 eV (ne_ped = 1.900e+19 m^-3, psi_ped = 0.9626, Delta = 0.0374)
#   psi_N_inner_boundary_new = 0.9626
# Percent change from previous T_e at psi_ped = 6.4361
# Setting up EPEDNN...
# EPED iter 3: 28 successful runs (best -> worst L2)
#   #  1  L2=0.1669  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   #  2  L2=0.1670  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   #  3  L2=0.1675  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   #  4  L2=0.1720  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   #  5  L2=0.1721  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   #  6  L2=0.1721  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   #  7  L2=0.1726  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   #  8  L2=0.1769  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   #  9  L2=0.1912  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 10  L2=0.1916  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 11  L2=0.1921  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   # 12  L2=0.1936  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 13  L2=0.1994  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   # 14  L2=0.2612  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   # 15  L2=0.2648  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   # 16  L2=0.3255  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   # 17  L2=0.3725  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   # 18  L2=0.3725  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 19  L2=0.3728  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   # 20  L2=0.3747  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   # 21  L2=0.3777  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   # 22  L2=0.3783  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 23  L2=0.3803  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 24  L2=0.3804  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   # 25  L2=0.3990  alpha_crit=1.0, C_KBM=1.0, De_chie_etg=1.0, nFC_x0=1e+16, ncx_x0_ratio=1.259, psi_N_inner=0.9625761709533587
#   # 26  L2=0.4014  alpha_crit=1.0, C_KBM=10.0, De_chie_etg=10.0, nFC_x0=1e+16, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
#   # 27  L2=0.4298  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=4.732, psi_N_inner=0.9625761709533587
#   # 28  L2=0.4486  alpha_crit=1.0, C_KBM=0.1, De_chie_etg=0.1, nFC_x0=100000000000000.0, ncx_x0_ratio=17.783, psi_N_inner=0.9625761709533587
# Best normalized L2 = 0.1669
# Pedestal height: 0.00961660009022213 MPa, Pedestal width: 0.037844809731720296 (psi_N)
# Normalized pedestal pressure height and width tolerance: 0.03529538227944495
#   Te_ped = 1618.9 eV, T_sep = 155.1 eV (ne_ped = 1.854e+19 m^-3, psi_ped = 0.9622, Delta = 0.0378)
#   psi_N_inner_boundary_new = 0.9622
# Percent change from previous T_e at psi_ped = 4.6751
# Setting up EPEDNN...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 profiles_loop_solve(
#       2     MHD_FP = MHD_FP,
#       3     KPROF_FP = KPROF_FP,
#       4     ne_success_fp = ne_success_fp,
#       5     success_fp = success_fp,
#       6     failure_fp = failure_fp,
#       7     error_messages_fp = error_messages_fp,
#       8     N = N,
#       9     x_res = x_res,
#      10     eped_tol_max = eped_tol_max,
#      11     verbose = verbose,
#      12 )
#
# File ~/software/saarelma-conner-ped/src/profiles_loop_solve.py:189, in profiles_loop_solve(MHD_FP, KPROF_FP, ne_success_fp, success_fp, failure_fp, error_messages_fp, initial_guess, ne_inner_bc, x_res, N, P_tot_e, psi_N_inner, alpha_crits_minmax, C_KBMs_minmax, De_chie_etgs_minmax, nFC_x0s_minmax, ncx_x0_ratios_minmax, eped_tol_max, eped_iter_max, verbose)
#     186         best_l2, best_x, best_ne = l2, x_i, ne_i
#     188 if best_ne is None:
# --> 189     raise RuntimeError(f"No successful runs found in {ne_success_fp}")
#     191 ranked_runs.sort(key=lambda r: r[0])
#     192 print(f"EPED iter {eped_iter}: {len(ranked_runs)} successful runs (best -> worst L2)")
#
# RuntimeError: No successful runs found in success_profloop
