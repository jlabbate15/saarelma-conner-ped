# %%
from solver import saarelma_connor
test_model = saarelma_connor(
        P_tot_e = 5e6, # W, total heating power given to electrons (can be assumed to be half the total heating power according to S. Saarelma et al 2023 Nucl. Fusion 63 052002), will be read from TokTox
        alpha_crit = 1,
        C_KBM = 0.1,
        De_chie_etg = 0.5,
        mhd_fp = 'g192185.02440', # filepath to MHD paramter file
        kprof_fp = '/Users/nelsonlab/codes/Equilibria/p193754.1850.0', # filepath to kinetic paramter file
)
test_model.solve()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.49e-01       6.64e+05          200            199
#        2          9.49e-01       2.21e+06          399            398
#        3          9.49e-01       3.31e+06          797            796
#        4          9.49e-01       2.87e+07         1593           1592
#        5          9.49e-01       7.16e+07         3185           3184
#        6          9.49e-01       1.20e+08         6369          (6368)
# Number of nodes is exceeded after iteration 6.
# Maximum relative residual: 9.49e-01
# Maximum boundary residual: 1.20e+08
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 10
#       1 from solver import saarelma_connor
#       2 test_model = saarelma_connor(
#       3         P_tot_e = 5e6, # W, total heating power given to electrons (can be assumed to be half the total heating power according to S. Saarelma et al 2023 Nucl. Fusion 63 052002), will be read from TokTox
#       4         alpha_crit = 1,
#    (...)      8         kprof_fp = '/Users/nelsonlab/codes/Equilibria/p193754.1850.0', # filepath to kinetic paramter file
#       9 )
# ---> 10 test_model.solve()
#
# File ~/codes/saarelma-conner-ped/src/solver.py:788, in saarelma_connor.solve(self, soln_method, tol, max_iter, x_res)
#     784 self.setup_solver_grids(res=x_res)
#     786 if soln_method == 'sc_2order':
#     787     # --- Step 1: first step (Eq 16, no CX neutrals) ---
# --> 788     self.first_step()
#     790     # --- Step 2: iterate full Eq 15 ---
#     791     for i in range(max_iter):
#     792
#     793         # Interpolate required parameters to x_sol_prev grid (interpolating from initial grid to minimize errors)
#
# File ~/codes/saarelma-conner-ped/src/solver.py:748, in saarelma_connor.first_step(self, resolution)
#     746 sol = solve_bvp(ode, bc, x_grid, Y_guess, max_nodes=10000,verbose=2,tol=0.9)
#     747 if not sol.success:
# --> 748     raise RuntimeError(f"first_step BVP failed: {sol.message}")
#     750 self.sol = sol
#
# RuntimeError: first_step BVP failed: The maximum number of mesh nodes is exceeded.

# %%
print(test_model.T_e_K)
# Out:
# [27004472.3338     27120355.07052001 27336837.39112    27488450.44492
#  27618177.374      27735731.1616     27832919.0166     27920533.1426
#  27997146.18364    28058905.43908    28108712.03892    28147030.16396
#  28172827.01192    28188458.30036    28192612.71852    28187541.54328
#  28171446.07404001 28146624.00576    28113423.47404    28070185.03252
#  28019055.5174     27959965.30156    27893355.35676    27819817.51352
