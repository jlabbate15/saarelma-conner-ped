# %%
from solver import saarelma_connor
test_model = saarelma_connor(
        P_tot_e = 5e6, # W, total heating power given to electrons (can be assumed to be half the total heating power according to S. Saarelma et al 2023 Nucl. Fusion 63 052002), will be read from TokTox
        alpha_crit = 1,
        C_KBM = 0.1,
        De_chie_etg = 0.5,
        mhd_fp = 'g192185.02440', # filepath to MHD paramter file
        kprof_fp = '/Users/nelsonlab/codes/Equilibria/p193754.1850.0', # filepath to kinetic paramter file
)
test_model.solve()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.74e+00       4.79e+11          64             126
#        2          1.34e+00       3.97e+24          190            378
#        3          1.34e+00       4.74e+46          568           1134
# Singular Jacobian encountered when solving the collocation system on iteration 4.
# Maximum relative residual: nan
# Maximum boundary residual: nan
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:459: RuntimeWarning: overflow encountered in dot
#   cost = np.dot(step, step)
# /Users/nelsonlab/codes/saarelma-conner-ped/src/solver.py:726: RuntimeWarning: overflow encountered in multiply
#   rhs = (ne * D * (self.S_i + self.S_cx) / self.V_FC) * (dnedx - self.dne_dx_neginf)
# /Users/nelsonlab/codes/saarelma-conner-ped/src/solver.py:727: RuntimeWarning: invalid value encountered in subtract
#   d2nedx2 = (rhs - dfdx * dnedx) / f
# /Users/nelsonlab/codes/saarelma-conner-ped/src/solver.py:727: RuntimeWarning: overflow encountered in divide
#   d2nedx2 = (rhs - dfdx * dnedx) / f
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:313: RuntimeWarning: overflow encountered in multiply
#   4 * f_middle)
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:312: RuntimeWarning: invalid value encountered in subtract
#   col_res = y[:, 1:] - y[:, :-1] - h / 6 * (f[:, :-1] + f[:, 1:] +
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:39: RuntimeWarning: invalid value encountered in subtract
#   hi = y_new[i] - y[i]
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:41: RuntimeWarning: invalid value encountered in subtract
#   df_dy[:, i, :] = (f_new - f0) / hi
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:568: RuntimeWarning: invalid value encountered in divide
#   r_middle /= 1 + np.abs(f_middle)
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:569: RuntimeWarning: invalid value encountered in divide
#   r1 /= 1 + np.abs(f1)
# /Users/nelsonlab/anaconda3/envs/sc_ped/lib/python3.14/site-packages/scipy/integrate/_bvp.py:570: RuntimeWarning: invalid value encountered in divide
#   r2 /= 1 + np.abs(f2)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 10
#       1 from solver import saarelma_connor
#       2 test_model = saarelma_connor(
#       3         P_tot_e = 5e6, # W, total heating power given to electrons (can be assumed to be half the total heating power according to S. Saarelma et al 2023 Nucl. Fusion 63 052002), will be read from TokTox
#       4         alpha_crit = 1,
#    (...)      8         kprof_fp = '/Users/nelsonlab/codes/Equilibria/p193754.1850.0', # filepath to kinetic paramter file
#       9 )
# ---> 10 test_model.solve()
#
# File ~/codes/saarelma-conner-ped/src/solver.py:782, in saarelma_connor.solve(self, soln_method, tol, max_iter, x_res)
#     778 self.setup_solver_grids(res=x_res)
#     780 if soln_method == 'sc_2order':
#     781     # --- Step 1: first step (Eq 16, no CX neutrals) ---
# --> 782     self.first_step()
#     784     # --- Step 2: iterate full Eq 15 ---
#     785     for i in range(max_iter):
#     786
#     787         # Interpolate required parameters to x_sol_prev grid (interpolating from initial grid to minimize errors)
#
# File ~/codes/saarelma-conner-ped/src/solver.py:742, in saarelma_connor.first_step(self, resolution)
#     740 sol = solve_bvp(ode, bc, self.x_init, Y_guess, max_nodes=10000,verbose=2)
#     741 if not sol.success:
# --> 742     raise RuntimeError(f"first_step BVP failed: {sol.message}")
#     744 self.sol = sol
#
# RuntimeError: first_step BVP failed: A singular Jacobian encountered when solving the collocation system.

# %%
print(test_model.V_th_e/3e8)
