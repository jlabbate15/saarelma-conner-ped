# %%
import matplotlib.pyplot as plt

# %%
from solver import saarelma_connor
test_model = saarelma_connor(
        P_tot_e = 5e6, # W, total heating power given to electrons (can be assumed to be half the total heating power according to S. Saarelma et al 2023 Nucl. Fusion 63 052002), will be read from TokTox
        alpha_crit = 1,
        C_KBM = 0.1,
        De_chie_etg = 0.5,
        mhd_fp = 'g192185.02440', # filepath to MHD paramter file
        kprof_fp = '/Users/nelsonlab/codes/Equilibria/p193754.1850.0', # filepath to kinetic paramter file
        verbose = True
)
test_model.solve()
# Out:
# first_step initial guess diagnostics
# -----------------------------------
# x span: -6.045e-02 -> 0.000e+00 (width=6.045e-02)
# S_i + S_cx: 1.947e-13
# V_FC: 1.079e+04
# target inner gradient: -1.298e+20
# n_e guess: min=9.684e+18, max=3.428e+19, maxabs=3.428e+19
# dn_e/dx guess: min=-9.682e+20, max=-1.296e+20, maxabs=9.682e+20
# D(x): min=1.335e+00, max=2.751e+00, maxabs=2.751e+00
# f(x): min=2.346e-02, max=4.840e-02, maxabs=4.840e-02
# df/dx: min=-1.013e+00, max=2.042e+00, maxabs=2.042e+00
# dn_e/dx - BC slope: min=-8.384e+20, max=1.509e+17, maxabs=8.384e+20
# reaction coefficient: min=2.409e-17, max=4.964e-17, maxabs=4.964e-17
# rhs term: min=-4.830e+23, max=2.023e+20, maxabs=4.830e+23
# transport term dfdx*dnedx: min=-1.977e+21, max=4.322e+20, maxabs=1.977e+21
# d2n_e/dx2 inferred: min=-1.719e+25, max=5.591e+21, maxabs=1.719e+25
# dimensionless |dn_e/dx| / (n_e/L): 1.707e+00
# dimensionless |d2n_e/dx2| / (n_e/L^2): 1.832e+03
# ode output shape: (2, 200)
# ode has nan: False, inf: False
# ode max abs: 1.725e+25
# Y_guess shape: (2, 200)
# BC residual: [0. 0.]
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.72e+01       0.00e+00          200            391
#        2          3.28e+00       0.00e+00          591            34
#        3          4.20e-01       0.00e+00          625            32
#        4          3.65e-01       0.00e+00          657            12
#        5          6.46e-02       0.00e+00          669             8
#        6          4.42e-02       0.00e+00          677             6
#        7          2.63e-02       0.00e+00          683             4
#        8          5.77e-03       0.00e+00          687             3
#        9          3.50e-03       0.00e+00          690             2
#       10          3.57e-03       0.00e+00          692             2
#       11          1.43e-03       0.00e+00          694             2
#       12          9.97e-04       0.00e+00          696             0
# Solved in 12 iterations, number of nodes 696.
# Maximum relative residual: 9.97e-04
# Maximum boundary residual: 0.00e+00
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 11
#       1 from solver import saarelma_connor
#       2 test_model = saarelma_connor(
#       3         P_tot_e = 5e6, # W, total heating power given to electrons (can be assumed to be half the total heating power according to S. Saarelma et al 2023 Nucl. Fusion 63 052002), will be read from TokTox
#       4         alpha_crit = 1,
#    (...)      9         verbose = True
#      10 )
# ---> 11 test_model.solve()
#
# File ~/codes/saarelma-conner-ped/src/solver.py:829, in saarelma_connor.solve(self, soln_method, tol, max_iter, x_res)
#     826 ne_sol_prev = self.sol.y[0] # not gauranteed to be the same grid as inputted to solve_bvp()
#     828 D_ped_int = interp1d(self.x_init, self.D_ped, kind='linear', bounds_error=False, fill_value='extrapolate')
# --> 829 S_i_int = interp1d(self.x_init, self.S_i_pres, kind='linear', bounds_error=False, fill_value='extrapolate')
#     830 S_cx_int = interp1d(self.x_init, self.S_cx_pres, kind='linear', bounds_error=False, fill_value='extrapolate')
#     831 gradr_fsa_int = interp1d(self.x_init, self.gradr_fsa, kind='linear', bounds_error=False, fill_value='extrapolate')
#
# AttributeError: 'saarelma_connor' object has no attribute 'S_i_pres'

# %%
print(test_model.sol)
plt.plot(test_model.sol.x, test_model.sol.y[0])
# plt.plot(test_model.sol.x, test_model.sol.y[1])
plt.plot(test_model.x_init, test_model.n_e_pres)
plt.plot(-0.06,0,'o')
# Out:
#        message: The algorithm converged to the desired accuracy.
#        success: True
#         status: 0
#              x: [-6.045e-02 -6.043e-02 ... -3.038e-04  0.000e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x159d0bce0>
#              p: None
#              y: [[ 1.753e+19  1.752e+19 ...  9.723e+18  9.684e+18]
#                  [-1.298e+20 -1.298e+20 ... -1.292e+20 -1.292e+20]]
#             yp: [[-1.298e+20 -1.298e+20 ... -1.292e+20 -1.292e+20]
#                  [ 5.269e+20  3.415e+20 ... -1.245e+19 -1.204e+19]]
#  rms_residuals: [ 4.850e-04  4.842e-04 ...  4.327e-07  4.335e-07]
#          niter: 12
